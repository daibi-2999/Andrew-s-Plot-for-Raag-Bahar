# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Bahar.csv")

# %%
print(df.head(1))
# Out:
#     Song Name   P(S)=X1  P(r )= X2  P( R)= X3   P(g)=X4  P(G)=X5  P(M)=X6  \
# 0  Raga Bahar  0.313253          0   0.060241  0.096386        0  0.13253
#
#    P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0        0  0.072289        0  0.060241  0.120482  0.144578

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="blue")
